# %% [markdown]
# # Macaque CT-model's Experiment

# %%
import os
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pylab as plt
from matplotlib import gridspec
os.chdir('../')
from src.data_loading import LoadCSV, LoadCSVandVIDEO
from src.data_preprocessing.video import rotate_video, crop_video_depend_scanposition, downsample_video
from dimensionality_reduction import Autoencoder
from timeseries_modeling import Three_Layer_Feedforward_NN_using_ELM as TFNN_ELM

# %%
rcParams_dict = {
    'font.family':'Times New Roman',
    'mathtext.fontset':'stix',
    'font.size':15,
    'xtick.direction':'in',
    'ytick.direction':'in',
    'axes.linewidth':1.5,
    'xtick.major.size':8,
    'ytick.major.size':8,}
for key in rcParams_dict.keys():plt.rcParams[str(key)] = rcParams_dict[str(key)]

# %%
### DEFINE
SEED = 0
CSV_DIR = './data/macaque_exvivo/CSV/'
AVI_DIR = './data/macaque_exvivo/AVI/'
DATA_NAME = '952'
SAMPLE_SPAN = [70000, 80010]
LINESCAN_PARAM = {'position':[190, 180], 'width':200}
ROTATE_ANGLE = -40
DOWNSAMPLE_FACTOR = 4
N_TRAIN = 4000
N_TEST = 4000
LATENT_SIZE_LIST = [2, 4, 6, 8, 10]
LATENT_SIZE = 6
SCALAR_TRAIN = MinMaxScaler()
SCALAR_TEST = MinMaxScaler()
BRIGHTNESS_CORRECTION = 1.
OUTLIER_CORRECTION = 0#1e-10

# %%
### Load data
[], video, video_t = LoadCSVandVIDEO(CSV_DIR+DATA_NAME+".csv", [], SAMPLE_SPAN, AVI_DIR+DATA_NAME+".avi")
### Preprocess
video = rotate_video(video, ROTATE_ANGLE)
video = crop_video_depend_scanposition(video, LINESCAN_PARAM)
video = downsample_video(video, DOWNSAMPLE_FACTOR)
video_shape = video.shape
X, T = (video.reshape(-1, video_shape[1]*video_shape[2])+OUTLIER_CORRECTION)/255., video_t
T -= T[0]
del video, video_t
### Split X into train & test sets
X_train, X_test = X[:N_TRAIN], X[N_TRAIN:N_TRAIN+N_TEST]
T_train, T_test = T[:N_TRAIN], T[N_TRAIN:N_TRAIN+N_TEST]
del X, T
### Scaling
X_train_scaled = SCALAR_TRAIN.fit_transform(X_train.copy())
X_test_scaled = SCALAR_TEST.fit_transform(X_test.copy())
# Out:
# Loading csv data
# file path | ./data/macaque_exvivo/CSV/952.csv
# data list |
# Loading video data
# file path | ./data/macaque_exvivo/AVI/952.avi

# %%
### Setting autoencoder
AE_PARAMETERS={"learning_rate": 5e-4,
                "loss_function": "mse",
                "train_size_rate": 0.8,
                "batch_size": 128,
                "epoch": 200,
                "early_stopping": False,
                "early_stopping_round": 10,
                "output_log": False}

### Numerical experiments
loss_valid_list = []
for i, latent_size in enumerate(LATENT_SIZE_LIST):
    print("Experiment"+str(i+1)+" (Latent size: "+str(latent_size)+") ")
    AE_MODEL = Autoencoder(X_train_scaled.shape[1], latent_size, seed=SEED)
    AE_MODEL.fit(X_train_scaled, AE_PARAMETERS)
    loss_valid_list.append(AE_MODEL.loss_valid)
    print("   loss of valid data: "+str(AE_MODEL.loss_valid[-1]))
    del AE_MODEL
# Out:
# Experiment1 (Latent size: 2)
#    loss of valid data: 0.011475112289190292
# Experiment2 (Latent size: 4)
#    loss of valid data: 0.008024976588785648
# Experiment3 (Latent size: 6)
#    loss of valid data: 0.00608808733522892
# Experiment4 (Latent size: 8)
#    loss of valid data: 0.004859134089201689
# Experiment5 (Latent size: 10)
#    loss of valid data: 0.004060631617903709

# %%
def autoencoder_validloss_list(loss_valid_list, label_list, threshold_value=0.01, 
                             c=('g', 'b', 'r', 'm', 'c'), 
                             ls=((0, (2, 1)), (0, (5, 1)), (0, (8, 1)), (0, (2, 1, 1, 1)), (0, (5, 1, 1, 1))),
                             y_lim=(0, None)) :
    spec = gridspec.GridSpec(ncols=1, nrows=1)
    fig = plt.figure(figsize=(10, 3))
    ax = fig.add_subplot(spec[0])
    ax.axhline(y=threshold_value, linestyle='-', c='k')
    for i in range(len(loss_valid_list)): ax.plot(np.arange(1, len(loss_valid_list[i])+1), loss_valid_list[i], lw=2, c=c[i], linestyle=ls[i], label=label_list[i])
    ax.set_xlabel(r'Epochs')
    ax.set_ylabel(r'Loss of input and output layers')
    ax.set_ylim(y_lim[0], y_lim[1])
    fig.legend(loc="upper center", facecolor="white", edgecolor="white", bbox_to_anchor=(0.5, 1.06), ncol=len(loss_valid_list))
    plt.show()

# %%
autoencoder_validloss_list(loss_valid_list, 
                           [r"$N_l=$"+str(LATENT_SIZE_LIST[0]),
                            r"$N_l=$"+str(LATENT_SIZE_LIST[1]),
                            r"$N_l=$"+str(LATENT_SIZE_LIST[2]),
                            r"$N_l=$"+str(LATENT_SIZE_LIST[3]),
                            r"$N_l=$"+str(LATENT_SIZE_LIST[4])], 
                            y_lim=(None, 0.02))

# %%
### Setting autoencoder
AE_PARAMETERS={"learning_rate": 5e-4,
                "loss_function": "mse",
                "train_size_rate": 0.8,
                "batch_size": 128,
                "epoch": 427,
                "early_stopping": False,
                "early_stopping_round": 10,
                "output_log": True}

### Numerical experiments
AE_MODEL = Autoencoder(X_train_scaled.shape[1], LATENT_SIZE, seed=SEED)
AE_MODEL.fit(X_train_scaled, AE_PARAMETERS)
x_test = AE_MODEL.transform(X_test_scaled)
X_test_hat = SCALAR_TEST.inverse_transform(AE_MODEL.inverse_transform(AE_MODEL.transform(X_test_scaled)))
# Out:
# Epoch 1/427
# 25/25 [==============================] - 1s 13ms/step - loss: 0.1020 - val_loss: 0.0814
# Epoch 2/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0615 - val_loss: 0.0459
# Epoch 3/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0404 - val_loss: 0.0346
# Epoch 4/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0315 - val_loss: 0.0270
# Epoch 5/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0257 - val_loss: 0.0230
# Epoch 6/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0229 - val_loss: 0.0209
# Epoch 7/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0208 - val_loss: 0.0188
# Epoch 8/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0185 - val_loss: 0.0163
# Epoch 9/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0161 - val_loss: 0.0144
# Epoch 10/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0145 - val_loss: 0.0132
# Epoch 11/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0136 - val_loss: 0.0125
# Epoch 12/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 13/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0127 - val_loss: 0.0118
# Epoch 14/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0124 - val_loss: 0.0116
# Epoch 15/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.0113
# Epoch 16/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0120 - val_loss: 0.0111
# Epoch 17/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 18/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0116 - val_loss: 0.0107
# Epoch 19/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0114 - val_loss: 0.0105
# Epoch 20/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0111 - val_loss: 0.0102
# Epoch 21/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0109 - val_loss: 0.0100
# Epoch 22/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0107 - val_loss: 0.0098
# Epoch 23/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0106 - val_loss: 0.0096
# Epoch 24/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0104 - val_loss: 0.0095
# Epoch 25/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0102 - val_loss: 0.0093
# Epoch 26/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0101 - val_loss: 0.0092
# Epoch 27/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0099 - val_loss: 0.0090
# Epoch 28/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0098 - val_loss: 0.0089
# Epoch 29/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0097 - val_loss: 0.0088
# Epoch 30/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0095 - val_loss: 0.0087
# Epoch 31/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0094 - val_loss: 0.0085
# Epoch 32/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0093 - val_loss: 0.0084
# Epoch 33/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0092 - val_loss: 0.0083
# Epoch 34/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0091 - val_loss: 0.0082
# Epoch 35/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0090 - val_loss: 0.0081
# Epoch 36/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0089 - val_loss: 0.0080
# Epoch 37/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0088 - val_loss: 0.0080
# Epoch 38/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0087 - val_loss: 0.0079
# Epoch 39/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0087 - val_loss: 0.0078
# Epoch 40/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0086 - val_loss: 0.0078
# Epoch 41/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0085 - val_loss: 0.0077
# Epoch 42/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0085 - val_loss: 0.0076
# Epoch 43/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0084 - val_loss: 0.0076
# Epoch 44/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0083 - val_loss: 0.0075
# Epoch 45/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0083 - val_loss: 0.0074
# Epoch 46/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0082 - val_loss: 0.0074
# Epoch 47/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0082 - val_loss: 0.0073
# Epoch 48/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0081 - val_loss: 0.0073
# Epoch 49/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0081 - val_loss: 0.0072
# Epoch 50/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0072
# Epoch 51/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0071
# Epoch 52/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0071
# Epoch 53/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0070
# Epoch 54/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0078 - val_loss: 0.0070
# Epoch 55/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0078 - val_loss: 0.0069
# Epoch 56/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0078 - val_loss: 0.0069
# Epoch 57/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0077 - val_loss: 0.0069
# Epoch 58/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0077 - val_loss: 0.0068
# Epoch 59/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0077 - val_loss: 0.0068
# Epoch 60/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0076 - val_loss: 0.0068
# Epoch 61/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 0.0068
# Epoch 62/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0076 - val_loss: 0.0067
# Epoch 63/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 0.0067
# Epoch 64/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0075 - val_loss: 0.0067
# Epoch 65/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0075 - val_loss: 0.0067
# Epoch 66/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0075 - val_loss: 0.0067
# Epoch 67/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0075 - val_loss: 0.0066
# Epoch 68/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0075 - val_loss: 0.0066
# Epoch 69/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0075 - val_loss: 0.0066
# Epoch 70/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0074 - val_loss: 0.0066
# Epoch 71/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0074 - val_loss: 0.0066
# Epoch 72/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0074 - val_loss: 0.0066
# Epoch 73/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0074 - val_loss: 0.0066
# Epoch 74/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0074 - val_loss: 0.0066
# Epoch 75/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0074 - val_loss: 0.0066
# Epoch 76/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0074 - val_loss: 0.0065
# Epoch 77/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0074 - val_loss: 0.0065
# Epoch 78/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0074 - val_loss: 0.0065
# Epoch 79/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0073 - val_loss: 0.0065
# Epoch 80/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0073 - val_loss: 0.0065
# Epoch 81/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0073 - val_loss: 0.0065
# Epoch 82/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0073 - val_loss: 0.0065
# Epoch 83/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0073 - val_loss: 0.0065
# Epoch 84/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0073 - val_loss: 0.0065
# Epoch 85/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0073 - val_loss: 0.0065
# Epoch 86/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0073 - val_loss: 0.0065
# Epoch 87/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0073 - val_loss: 0.0065
# Epoch 88/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0073 - val_loss: 0.0065
# Epoch 89/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0073 - val_loss: 0.0064
# Epoch 90/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0073 - val_loss: 0.0064
# Epoch 91/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0073 - val_loss: 0.0064
# Epoch 92/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 93/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 94/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 95/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 96/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 97/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 98/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 99/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 100/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 101/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 102/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 103/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 104/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 105/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 106/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 107/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 108/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 109/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 110/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 111/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 112/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0072 - val_loss: 0.0063
# Epoch 113/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 114/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 115/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 116/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 117/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 118/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 119/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 120/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 121/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 122/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 123/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 124/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 125/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 126/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 127/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 128/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 129/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 130/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 131/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 132/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 133/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 134/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 135/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 136/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 137/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 138/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 139/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 140/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 141/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0063
# Epoch 142/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0063
# Epoch 143/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 144/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 145/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 146/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 147/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 148/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 149/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 150/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 151/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 152/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 153/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 154/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 155/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 156/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 157/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 158/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 159/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 160/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 161/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 162/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 163/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 164/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 165/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 166/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 167/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 168/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 169/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 170/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 171/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 172/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 173/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 174/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 175/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 176/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 177/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 178/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 179/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 180/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 181/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 182/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 183/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 184/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 185/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 186/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 187/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 188/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 189/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 190/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 191/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 192/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 193/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 194/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 195/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 196/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 197/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 198/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 199/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 200/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 201/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 202/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 203/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 204/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 205/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 206/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 207/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 208/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 209/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 210/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 211/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 212/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 213/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 214/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 215/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 216/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 217/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 218/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 219/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 220/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 221/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 222/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 223/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 224/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 225/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 226/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 227/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 228/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 229/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 230/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 231/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 232/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 233/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 234/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 235/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 236/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 237/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 238/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 239/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 240/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 241/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 242/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 243/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 244/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 245/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 246/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 247/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 248/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 249/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 250/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 251/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 252/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 253/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 254/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 255/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 256/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 257/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 258/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 259/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 260/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 261/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 262/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 263/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 264/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 265/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 266/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 267/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 268/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 269/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 270/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 271/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 272/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 273/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 274/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 275/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 276/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 277/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 278/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 279/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 280/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 281/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 282/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 283/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 284/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 285/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 286/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 287/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 288/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 289/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 290/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 291/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 292/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 293/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 294/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 295/427
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 296/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 297/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 298/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 299/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0059
# Epoch 300/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 301/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 302/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 303/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 304/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 305/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 306/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 307/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 308/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 309/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 310/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 311/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 312/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 313/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 314/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 315/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 316/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 317/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 318/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 319/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 320/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 321/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 322/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 323/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 324/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 325/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 326/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 327/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 328/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 329/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 330/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 331/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 332/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 333/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 334/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 335/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 336/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 337/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 338/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 339/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 340/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 341/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 342/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 343/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 344/427
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 345/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 346/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 347/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 348/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 349/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 350/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 351/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 352/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 353/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 354/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 355/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 356/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 357/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 358/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 359/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0058
# Epoch 360/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 361/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 362/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 363/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 364/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 365/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 366/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 367/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 368/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 369/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 370/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 371/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 372/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 373/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 374/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 375/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 376/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 377/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 378/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 379/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 380/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 381/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 382/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 383/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 384/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 385/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 386/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 387/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 388/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 389/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 390/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 391/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 392/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 393/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 394/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 395/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 396/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 397/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 398/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 399/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 400/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 0.0057
# Epoch 401/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 402/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 403/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 404/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 405/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 406/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 407/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 408/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 409/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 410/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 411/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 412/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 413/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 414/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 415/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 416/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 417/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 418/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 419/427
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 420/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 421/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 422/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 423/427
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 424/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 425/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 426/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057
# Epoch 427/427
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0057

# %%
def line_scanning(video, linescan_params):
    position = linescan_params['position']
    width = linescan_params['width']
    return video[:, (position[0]-int(width/2)):(position[0]+int(width/2)), position[1]]

def autoencoder_input_output(X_input, X_output, T, n_plt, linescan_params, video_shape):
    X_input = line_scanning(X_input.reshape(-1, video_shape[1], video_shape[2]), linescan_params)
    X_output = line_scanning(X_output.reshape(-1, video_shape[1], video_shape[2]), linescan_params)
    aspect = n_plt/(X_input.shape[1]*80000)
    t_min = T[0]
    t_max = T[n_plt - 1] if n_plt <= len(T) else T[-1]

    spec = gridspec.GridSpec(ncols=2, nrows=3, width_ratios=[1, 0.04], height_ratios=[1, 1, 1], wspace=0)
    fig = plt.figure(figsize=(10, 4))

    ax = fig.add_subplot(spec[0])
    img = ax.imshow(X_input[:n_plt].T, aspect=aspect, cmap="gray", 
              extent=[t_min, t_max, 1, X_input.shape[1]], 
              vmax=np.max(X_input[:n_plt]), vmin=np.min(X_input[:n_plt]))
    ax.set_ylabel(r'$X(t)$')
    ax.tick_params(labelleft=False, labelbottom=False, left=False)

    ax = fig.add_subplot(spec[1])
    ax.axis("off")
    fig.colorbar(img, location='right', ax=ax, shrink=10)

    ax = fig.add_subplot(spec[2])
    img = ax.imshow(X_output[:n_plt].T, aspect=aspect, cmap="gray", 
              extent=[t_min, t_max, 1, X_output.shape[1]], 
              vmax=np.max(X_input[:n_plt]), vmin=np.min(X_input[:n_plt]))
    ax.set_ylabel(r'$\hat{X}(t)$')
    ax.tick_params(labelleft=False, labelbottom=False, left=False)

    ax = fig.add_subplot(spec[3])
    ax.axis("off")
    fig.colorbar(img, location='right', ax=ax, shrink=10)

    ax = fig.add_subplot(spec[4])
    img = ax.imshow((X_output[:n_plt] - X_input[:n_plt]).T, aspect=aspect, cmap="seismic", 
              extent=[t_min, t_max, 1, X_output.shape[1]], 
              vmax=np.max(np.abs(X_input[:n_plt])), vmin=-np.max(np.abs(X_input[:n_plt])))
    ax.set_ylabel(r'$\hat{X}(t)-X(t)$')
    ax.set_xlabel(r'Time [s]')
    ax.tick_params(labelleft=False, left=False)

    ax = fig.add_subplot(spec[5])
    ax.axis("off")
    fig.colorbar(img, location='right', ax=ax, shrink=10)

    plt.show()

linescan_params = {'position':[video_shape[1]//2, video_shape[1]//2], 'width':video_shape[1]/1}
autoencoder_input_output(X_test*255.*BRIGHTNESS_CORRECTION, X_test_hat*255.*BRIGHTNESS_CORRECTION, T_test, 1000,
                         linescan_params, video_shape, )

# %%
def autoencoder_latent(x, T, n_plt, n_attractor, sort=True):
    if sort: x = x[:, np.argsort(np.var(x, axis=0))[::-1]]
        
    spec = gridspec.GridSpec(ncols=2, nrows=3, height_ratios=[1, 1, 1], width_ratios=[1.5, 1], wspace=0.05)
    fig = plt.figure(figsize=(10, 4))

    ax = fig.add_subplot(spec[0, 0])
    ax.plot(T[:n_plt], x[:, 0][:n_plt], '-', c='k')
    ax.set_xlim(T[:n_plt][0], T[:n_plt][-1])
    ax.set_ylabel(r'$z_{1}$')
    ax.tick_params(labelbottom=False)

    ax = fig.add_subplot(spec[1, 0])
    ax.plot(T[:n_plt], x[:, 1][:n_plt], '-', c='k')
    ax.set_xlim(T[:n_plt][0], T[:n_plt][-1])
    ax.set_ylabel(r'$z_{2}$')
    ax.tick_params(labelbottom=False)

    ax = fig.add_subplot(spec[2, 0])
    ax.plot(T[:n_plt], x[:, 2][:n_plt], '-', c='k')
    ax.set_xlim(T[:n_plt][0], T[:n_plt][-1])
    ax.set_ylabel(r'$z_{3}$')
    ax.set_xlabel(r'Time [s]')

    ax = fig.add_subplot(spec[:, 1], projection='3d')
    ax.plot(x[:n_attractor, 0], x[:n_attractor, 1], x[:n_attractor, 2], '.', ms=1, c='k')
    ax.set_xlabel(r'$z_{1}$', labelpad=-15)
    ax.set_ylabel(r'$z_{2}$', labelpad=-15)
    ax.set_zlabel(r'$z_{3}$', labelpad=-15)
    ax.tick_params(labelbottom=False, labelleft=False, labelright=False)
    #ax.set_box_aspect((1,1,1))
    plt.show()

autoencoder_latent(x_test, T_test, 4000, None, sort=True)

# %%
def rmse(X, X_hat):
    return np.sqrt(np.sum((X - X_hat)**2, axis=1) / X.shape[1])

def timeseries_modeling(x, x_hat, T, n_plt, rmse_lim=[0, 25], sort=True):
    x_rmse = rmse(x[:n_plt], x_hat[:n_plt])
    if sort:
        x_ = x
        x = x[:, np.argsort(np.var(x_, axis=0))[::-1]]
        x_hat = x_hat[:, np.argsort(np.var(x_, axis=0))[::-1]]

    spec = gridspec.GridSpec(ncols=1, nrows=4, height_ratios=[1, 1, 1, 1])
    fig = plt.figure(figsize=(10, 6))

    ax = fig.add_subplot(spec[0])
    ax.plot(T[:n_plt], x[:, 0][:n_plt], '-', c='k', label='Exp.')
    ax.plot(T[:n_plt], x_hat[:, 0][:n_plt], '--', c='r', label='Model')
    ax.set_xlim(T[:n_plt][0], T[:n_plt][-1])
    ax.set_ylabel(r'$z_{1}$')
    ax.tick_params(labelbottom=False)
    fig.legend(loc="upper center", facecolor="white", edgecolor="white", bbox_to_anchor=(0.5, 0.97), ncol=2)

    ax = fig.add_subplot(spec[1])
    ax.plot(T[:n_plt], x[:, 1][:n_plt], '-', c='k')
    ax.plot(T[:n_plt], x_hat[:, 1][:n_plt], '--', c='r')
    ax.set_xlim(T[:n_plt][0], T[:n_plt][-1])
    ax.set_ylabel(r'$z_{2}$')
    ax.tick_params(labelbottom=False)

    ax = fig.add_subplot(spec[2])
    ax.plot(T[:n_plt], x[:, 2][:n_plt], '-', c='k')
    ax.plot(T[:n_plt], x_hat[:, 2][:n_plt], '--', c='r')
    ax.set_xlim(T[:n_plt][0], T[:n_plt][-1])
    ax.set_ylabel(r'$z_{3}$')
    ax.tick_params(labelbottom=False)

    ax = fig.add_subplot(spec[3])
    ax.plot(T[:n_plt], x_rmse, lw=1, c='b')
    ax.set_xlim(T[:n_plt][0], T[:n_plt][-1])
    ax.set_ylabel(r'RMSE')
    ax.set_xlabel(r'Time [s]')
    ax.set_ylim(rmse_lim[0], rmse_lim[-1])

    plt.show()

def timeseries_modeling_3d(x, x_hat, T, n_plt, sort=True):
    if sort:
        x_ = x
        x = x[:, np.argsort(np.var(x_, axis=0))[::-1]]
        x_hat = x_hat[:, np.argsort(np.var(x_, axis=0))[::-1]]

    spec = gridspec.GridSpec(ncols=2, nrows=1, wspace=0.1)
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(spec[0], projection='3d')
    ax.set_title('Exp.', loc='center', fontsize=plt.rcParams['font.size'], pad=-5)
    ax.plot(x[:n_plt, 0], x[:n_plt, 1], x[:n_plt, 2], '.', ms=2, c='k')
    ax.set_xlabel(r'$z_{1}$', labelpad=-15)
    ax.set_ylabel(r'$z_{2}$', labelpad=-15)
    ax.set_zlabel(r'$z_{3}$', labelpad=-15)
    ax.tick_params(labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    #ax.set_box_aspect((1,1,1))

    ax = fig.add_subplot(spec[1], projection='3d')
    ax.set_title('Model', loc='center', fontsize=plt.rcParams['font.size'], pad=-5)
    ax.plot(x_hat[:n_plt, 0], x_hat[:n_plt, 1], x_hat[:n_plt, 2], '.', ms=2, c='r')
    ax.set_xlabel(r'$z_{1}$', labelpad=-15)
    ax.set_ylabel(r'$z_{2}$', labelpad=-15)
    ax.set_zlabel(r'$z _{3}$', labelpad=-15)
    ax.tick_params(labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    #ax.set_box_aspect((1,1,1))

    plt.show()

def timeseries_modeling_lyaqunov(lyapunov_exponent, x_lim=[0, None], y_lim=[None, None]):
        
        spec = gridspec.GridSpec(ncols=1, nrows=1)
        fig = plt.figure(figsize=(10, 3.5))

        ax = fig.add_subplot(spec[0])
        ax.axhline(y=0, linestyle='--', c='k')
        ax.plot(np.arange(1, lyapunov_exponent.shape[0]+1), lyapunov_exponent, 'o', ms=5, c='b'   )
        ax.set_ylabel(r'Lyapunov enponents')
        ax.set_yscale('symlog', linthresh=1e+1)
        ax.set_xlim(x_lim[0], x_lim[-1])
        ax.set_ylim(y_lim[0], y_lim[-1])
        ax.get_xaxis().set_major_formatter(plt.FormatStrFormatter(r'$\lambda_{%d}$'))

        plt.show()

def timeseries_modeling_image(X, X_hat, T, n_plt, linescan_params, video_shape, rmse_lim=[0, 45]):
    x_rmse = rmse(X[:n_plt], X_hat[:n_plt])
    X = line_scanning(X.reshape(-1, video_shape[1], video_shape[2]), linescan_params)
    X_hat = line_scanning(X_hat.reshape(-1, video_shape[1], video_shape[2]), linescan_params)
    aspect = n_plt/(X.shape[1]*75000)
    t_min = T[0]
    t_max = T[n_plt - 1] if n_plt <= len(T) else T[-1]
    #x_rmse = rmse(X[:n_plt], X_hat[:n_plt])

    spec = gridspec.GridSpec(ncols=2, nrows=4, width_ratios=[1, 0.04], height_ratios=[1, 1, 1, 1], wspace=0)
    fig = plt.figure(figsize=(10, 6))

    ax = fig.add_subplot(spec[0])
    img = ax.imshow(X[:n_plt].T, aspect=aspect, cmap="gray", 
              extent=[t_min, t_max, 1, X.shape[1]], 
              vmax=255, vmin=0)
    ax.set_ylabel(r'Exp.')
    ax.tick_params(labelleft=False, labelbottom=False, left=False)

    ax = fig.add_subplot(spec[1])
    ax.axis("off")
    fig.colorbar(img, location='right', ax=ax, shrink=10)

    ax = fig.add_subplot(spec[2])
    img = ax.imshow(X_hat[:n_plt].T, aspect=aspect, cmap="gray", 
              extent=[t_min, t_max, 1, X_hat.shape[1]], 
              vmax=255, vmin=0)
    ax.set_ylabel(r'Model')
    ax.tick_params(labelleft=False, labelbottom=False, left=False)

    ax = fig.add_subplot(spec[3])
    ax.axis("off")
    fig.colorbar(img, location='right', ax=ax, shrink=10)

    ax = fig.add_subplot(spec[4])
    img = ax.imshow((X_hat[:n_plt] - X[:n_plt]).T, aspect=aspect, cmap="seismic", 
              extent=[t_min, t_max, 1, X_hat.shape[1]], 
              vmax=np.max(np.abs(X[:n_plt])), vmin=-np.max(np.abs(X[:n_plt])))
    ax.set_ylabel(r'Error')
    ax.tick_params(labelleft=False, labelbottom=False, left=False)

    ax = fig.add_subplot(spec[5])
    ax.axis("off")
    fig.colorbar(img, location='right', ax=ax, shrink=10)

    ax = fig.add_subplot(spec[6])
    ax.plot(T[:n_plt], x_rmse, lw=1, c='b')
    ax.set_xlim(T[:n_plt][0], T[:n_plt][-1])
    ax.set_ylabel(r'RMSE')
    ax.set_xlabel(r'Time [s]')
    ax.set_ylim(rmse_lim[0], rmse_lim[-1])

    plt.show()

def timeseries_modeling_images(X, X_hat, T, step, video_shape, error_lim=[-100, 100], time_format='{:.3f}'):

    X = X.reshape(-1, video_shape[1], video_shape[2])
    X_hat = X_hat.reshape(-1, video_shape[1], video_shape[2])

    spec = gridspec.GridSpec(ncols=6, nrows=3, wspace=0.1, hspace=0.0 )
    fig = plt.figure(figsize=(10, 6))

    ax = fig.add_subplot(spec[0])
    idx = step*0
    #ax.set_title('Exp.', loc='left', fontsize=plt.rcParams['font.size'])
    ax.imshow(X[idx], cmap='gray', vmax=255, vmin=0)
    #ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.set_ylabel('Exp.')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[1])
    idx = step*1
    ax.imshow(X[idx], cmap='gray', vmax=255, vmin=0)
    #ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[2])
    idx = step*2
    ax.imshow(X[idx], cmap='gray', vmax=255, vmin=0)
    #ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[3])
    idx = step*3
    ax.imshow(X[idx], cmap='gray', vmax=255, vmin=0)
    #ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[4])
    idx = step*4
    ax.imshow(X[idx], cmap='gray', vmax=255, vmin=0)
    #ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[5])
    idx = step*5
    ax.imshow(X[idx], cmap='gray', vmax=255, vmin=0)
    #ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    
    ax = fig.add_subplot(spec[6])
    idx = step*0
    #ax.set_title('Model', loc='left', fontsize=plt.rcParams['font.size'])
    ax.imshow(X_hat[idx], cmap='gray', vmax=255, vmin=0)
    #ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.set_ylabel('Model')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[7])
    idx = step*1
    ax.imshow(X_hat[idx], cmap='gray', vmax=255, vmin=0)
    #ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[8])
    idx = step*2
    ax.imshow(X_hat[idx], cmap='gray', vmax=255, vmin=0)
    #ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[9])
    idx = step*3
    ax.imshow(X_hat[idx], cmap='gray', vmax=255, vmin=0)
    #ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[10])
    idx = step*4
    ax.imshow(X_hat[idx], cmap='gray', vmax=255, vmin=0)
    #ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[11])
    idx = step*5
    ax.imshow(X_hat[idx], cmap='gray', vmax=255, vmin=0)
    #ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)

    ax = fig.add_subplot(spec[12])
    idx = step*0
    #ax.set_title('Error', loc='left', fontsize=plt.rcParams['font.size'])
    ax.imshow(X[idx]-X_hat[idx], cmap='seismic', vmax=error_lim[-1], vmin=error_lim[0])
    ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.set_ylabel('Error')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[13])
    idx = step*1
    ax.imshow(X[idx]-X_hat[idx], cmap='seismic', vmax=error_lim[-1], vmin=error_lim[0])
    ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[14])
    idx = step*2
    ax.imshow(X[idx]-X_hat[idx], cmap='seismic', vmax=error_lim[-1], vmin=error_lim[0])
    ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[15])
    idx = step*3
    ax.imshow(X[idx]-X_hat[idx], cmap='seismic', vmax=error_lim[-1], vmin=error_lim[0])
    ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[16])
    idx = step*4
    ax.imshow(X[idx]-X_hat[idx], cmap='seismic', vmax=error_lim[-1], vmin=error_lim[0])
    ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    ax = fig.add_subplot(spec[17])
    idx = step*5
    ax.imshow(X[idx]-X_hat[idx], cmap='seismic', vmax=error_lim[-1], vmin=error_lim[0])
    ax.set_xlabel(str(time_format.format(T[idx]))+r'[s]')
    ax.tick_params(bottom=False, left=False, right=False, top=False,
        labelbottom=False, labelleft=False, labelright=False, labeltop=False)

    plt.show()

# %%
### Setting ELM
HIDDEN_SIZE = 200
INPUT_W_SCALE = 0.1
ACTIVE_FUNC = "tanh"
RIDGE_PARAM = 7e-2
RIDGE_PARAM = 7e-3
RIDGE_PARAM = 9e-3
RUN_SIZE = 2000
DT = T_test[1] - T_test[0]

### Timeseries modeling
x_train = AE_MODEL.transform(X_train_scaled)
FNN_MODEL = TFNN_ELM(x_train.shape[1], HIDDEN_SIZE, x_train.shape[1],
                     INPUT_W_SCALE, ACTIVE_FUNC, SEED)
FNN_MODEL.fit(x_train[:-1], x_train[1:], RIDGE_PARAM)
x_test_hat = FNN_MODEL.freerun(x_train[-1], RUN_SIZE)
timeseries_modeling(x_test, x_test_hat, T_test, 2000, sort=True)
timeseries_modeling_3d(x_test, x_test_hat, T_test, None, sort=True)

### Lyaqunov caluculation
lyapunov_exponent = FNN_MODEL.lyapunov_calculation(x_train[-1], RUN_SIZE, DT)
timeseries_modeling_lyaqunov(lyapunov_exponent[:], [0.1, 30], [-10**7, None])

### Reconstruct video
X_test_hat = SCALAR_TEST.inverse_transform(AE_MODEL.inverse_transform(x_test_hat))
timeseries_modeling_image(X_test*255.*BRIGHTNESS_CORRECTION, X_test_hat*255*BRIGHTNESS_CORRECTION, T_test, 2000, linescan_params, video_shape, [0, None])
timeseries_modeling_images(X_test*255.*BRIGHTNESS_CORRECTION, X_test_hat*255*BRIGHTNESS_CORRECTION, T_test, 200, video_shape, )

# %%
def timeseries_modeling_lyaqunov_cumsum(lyapunov_exponent, x_lim=[0, None], y_lim=[None, None], y_cumsum=[None, None]):
        
        spec = gridspec.GridSpec(ncols=2, nrows=1, wspace=0.4)
        fig = plt.figure(figsize=(10, 3))

        ax = fig.add_subplot(spec[0])
        ax.axhline(y=0, linestyle='--', c='k')
        ax.plot(np.arange(1, lyapunov_exponent.shape[0]+1), lyapunov_exponent, 'o', ms=5, c='b'   )
        ax.set_ylabel(r'Lyapunov enponents')
        ax.set_yscale('symlog', linthresh=1e+1)
        ax.set_xlim(x_lim[0], x_lim[-1])
        ax.set_ylim(y_lim[0], y_lim[-1])
        ax.get_xaxis().set_major_formatter(plt.FormatStrFormatter(r'$\lambda_{%d}$'))

        ax = fig.add_subplot(spec[1])
        #fractal_dimension = np.argmin(np.where(np.cumsum(lyapunov_exponent)>0, np.cumsum(lyapunov_exponent), 0))
        #ax.axvline(x=fractal_dimension, linestyle='--', c='k')
        ax.axhline(y=0, linestyle='--', c='k')
        #ax.text(fractal_dimension, np.cumsum(lyapunov_exponent)[-1], r'$D_{\lambda}$', fontsize=plt.rcParams['font.size'])
        ax.plot(np.arange(1, lyapunov_exponent.shape[0]+1), np.cumsum(lyapunov_exponent), 'o', ms=5, c='b'   )
        ax.set_ylabel(r'Cumlative sum')
        ax.set_yscale('symlog', linthresh=1e+1)
        ax.set_xlim(x_lim[0], x_lim[-1])
        ax.set_ylim(y_cumsum[0], y_cumsum[-1])
        ax.get_xaxis().set_major_formatter(plt.FormatStrFormatter(r'$\lambda_{%d}$'))

        plt.show()

timeseries_modeling_lyaqunov_cumsum(lyapunov_exponent[:], [0.1, 30], [-1e+8, 1e+3], [-1e+8, 1e+3])
